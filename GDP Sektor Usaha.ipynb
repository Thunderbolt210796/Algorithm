# %%
import pandas as pd
import numpy as np

# %%
GDP2000 = pd.read_csv(https://drive.google.com/file/d/1ZG9Qqx5CGbp3FQd7G4tqBJh811lUpX45/view?usp=sharing)
GDP2010 = pd.read_csv(https://drive.google.com/file/d/19JyqMf_sYWiinnG6PXD34ERq9L-yOKmG/view?usp=share_link)
GDP2000.head(5)
# Out:
#   <!DOCTYPE html><html><head><meta name="google" content="notranslate"><meta http-equiv="X-UA-Compatible" content="IE=edge;"><style nonce="fs-RGI5JjAskQrBM_hxxmg">@font-face{font-family:'Roboto';font-style:italic;font-weight:400;src:url(//fonts.gstatic.com/s/roboto/v18/KFOkCnqEu92Fr1Mu51xIIzc.ttf)format('truetype');}@font-face{font-family:'Roboto';font-style:normal;font-weight:300;src:url(//fonts.gstatic.com/s/roboto/v18/KFOlCnqEu92Fr1MmSU5fBBc9.ttf)format('truetype');}@font-face{font-family:'Roboto';font-style:normal;font-weight:400;src:url(//fonts.gstatic.com/s/roboto/v18/KFOmCnqEu92Fr1Mu4mxP.ttf)format('truetype');}@font-face{font-family:'Roboto';font-style:normal;font-weight:500;src:url(//fonts.gstatic.com/s/roboto/v18/KFOlCnqEu92Fr1MmEU9fBBc9.ttf)format('truetype');}@font-face{font-family:'Roboto';font-style:normal;font-weight:700;src:url(//fonts.gstatic.com/s/roboto/v18/KFOlCnqEu92Fr1MmWUlfBBc9.ttf)format('truetype');}</style><meta name="referrer" content="origin"><title>sektor
# ...

# %%
GDP2010.head(5)
# Out:
#   <!DOCTYPE html><html><head><meta name="google" content="notranslate"><meta http-equiv="X-UA-Compatible" content="IE=edge;"><style nonce="LPA_PL5yc7Wzd8NddxqXxQ">@font-face{font-family:'Roboto';font-style:italic;font-weight:400;src:url(//fonts.gstatic.com/s/roboto/v18/KFOkCnqEu92Fr1Mu51xIIzc.ttf)format('truetype');}@font-face{font-family:'Roboto';font-style:normal;font-weight:300;src:url(//fonts.gstatic.com/s/roboto/v18/KFOlCnqEu92Fr1MmSU5fBBc9.ttf)format('truetype');}@font-face{font-family:'Roboto';font-style:normal;font-weight:400;src:url(//fonts.gstatic.com/s/roboto/v18/KFOmCnqEu92Fr1Mu4mxP.ttf)format('truetype');}@font-face{font-family:'Roboto';font-style:normal;font-weight:500;src:url(//fonts.gstatic.com/s/roboto/v18/KFOlCnqEu92Fr1MmEU9fBBc9.ttf)format('truetype');}@font-face{font-family:'Roboto';font-style:normal;font-weight:700;src:url(//fonts.gstatic.com/s/roboto/v18/KFOlCnqEu92Fr1MmWUlfBBc9.ttf)format('truetype');}</style><meta name="referrer" content="origin"><title>sektor
# ...

# %%
GDP2000 = GDP2000.transpose()
GDP2010 = GDP2010.transpose()
GDP2000
# Out:
#                                                      0    1    \
# <!DOCTYPE html><html><head><meta name="google" ...  try{   /*
# 400                                                  NaN  NaN
# 500                                                  NaN  NaN
# 700" nonce="fs-RGI5JjAskQrBM_hxxmg"><link rel="...   NaN  NaN
# docs-fwds:"docs_sdf"                                 NaN  NaN
# ...                                                  ...  ...
# [[null.2                                             NaN  NaN
# null.202                                             NaN  NaN
# null.203                                             NaN  NaN
# https://www.gstatic.com/og/_/js/k=og.qtm.en_US....   NaN  NaN
# };this.gbar_=this.gbar_||{};(function(_){var wi...   NaN  NaN
#
#                                                                                         2    \
# <!DOCTYPE html><html><head><meta name="google" ...   Copyright The Closure Library Authors.
# ...

# %%
GDP2010.head(5)
# Out:
#                                                      0    1    \
# <!DOCTYPE html><html><head><meta name="google" ...  try{   /*
# 400                                                  NaN  NaN
# 500                                                  NaN  NaN
# 700" nonce="LPA_PL5yc7Wzd8NddxqXxQ"><link rel="...   NaN  NaN
# docs-fwds:"docs_sdf"                                 NaN  NaN
#
#                                                                                         2    \
# <!DOCTYPE html><html><head><meta name="google" ...   Copyright The Closure Library Authors.
# 400                                                                                     NaN
# 500                                                                                     NaN
# 700" nonce="LPA_PL5yc7Wzd8NddxqXxQ"><link rel="...                                      NaN
# docs-fwds:"docs_sdf"                                                                    NaN
#
# ...

# %%
#ubah header (sumber: https://www.statology.org/pandas-set-first-row-as-header/)

GDP2000.columns = GDP2000.iloc[0]
GDP2000 = GDP2000[1:]

GDP2010.columns = GDP2010.iloc[0]
GDP2010 = GDP2010[1:]

GDP2000.head(5)
# Out:
# <!DOCTYPE html><html><head><meta name="google" content="notranslate"><meta http-equiv="X-UA-Compatible" content="IE=edge;"><style nonce="fs-RGI5JjAskQrBM_hxxmg">@font-face{font-family:'Roboto';font-style:italic;font-weight:400;src:url(//fonts.gstatic.com/s/roboto/v18/KFOkCnqEu92Fr1Mu51xIIzc.ttf)format('truetype');}@font-face{font-family:'Roboto';font-style:normal;font-weight:300;src:url(//fonts.gstatic.com/s/roboto/v18/KFOlCnqEu92Fr1MmSU5fBBc9.ttf)format('truetype');}@font-face{font-family:'Roboto';font-style:normal;font-weight:400;src:url(//fonts.gstatic.com/s/roboto/v18/KFOmCnqEu92Fr1Mu4mxP.ttf)format('truetype');}@font-face{font-family:'Roboto';font-style:normal;font-weight:500;src:url(//fonts.gstatic.com/s/roboto/v18/KFOlCnqEu92Fr1MmEU9fBBc9.ttf)format('truetype');}@font-face{font-family:'Roboto';font-style:normal;font-weight:700;src:url(//fonts.gstatic.com/s/roboto/v18/KFOlCnqEu92Fr1MmWUlfBBc9.ttf)format('truetype');}</style><meta name="referrer" content="origin"><title>sektor u
# ...

# %%
GDP2010.head(5)
# Out:
# <!DOCTYPE html><html><head><meta name="google" content="notranslate"><meta http-equiv="X-UA-Compatible" content="IE=edge;"><style nonce="LPA_PL5yc7Wzd8NddxqXxQ">@font-face{font-family:'Roboto';font-style:italic;font-weight:400;src:url(//fonts.gstatic.com/s/roboto/v18/KFOkCnqEu92Fr1Mu51xIIzc.ttf)format('truetype');}@font-face{font-family:'Roboto';font-style:normal;font-weight:300;src:url(//fonts.gstatic.com/s/roboto/v18/KFOlCnqEu92Fr1MmSU5fBBc9.ttf)format('truetype');}@font-face{font-family:'Roboto';font-style:normal;font-weight:400;src:url(//fonts.gstatic.com/s/roboto/v18/KFOmCnqEu92Fr1Mu4mxP.ttf)format('truetype');}@font-face{font-family:'Roboto';font-style:normal;font-weight:500;src:url(//fonts.gstatic.com/s/roboto/v18/KFOlCnqEu92Fr1MmEU9fBBc9.ttf)format('truetype');}@font-face{font-family:'Roboto';font-style:normal;font-weight:700;src:url(//fonts.gstatic.com/s/roboto/v18/KFOlCnqEu92Fr1MmWUlfBBc9.ttf)format('truetype');}</style><meta name="referrer" content="origin"><title>sektor u
# ...

# %%
GDP2000 = GDP2000.reset_index()
GDP2010 = GDP2010.reset_index()

GDP2000.columns
# Out:
# Index(['index', 'try{', '/*', ' Copyright The Closure Library Authors.',
#        ' SPDX-License-Identifier: Apache-2.0', '*/', 'var ka',
#        '_.ia=function(){return _.p("Safari")&&!(_.ha()||_.p("Coast")||_.ca()||_.p("Edge")||_.p("Edg/")||_.p("OPR")||_.fa()||_.p("Silk")||_.p("Android"))};_.ha=function(){return(_.p("Chrome")||_.p("CriOS"))&&!_.p("Edge")||_.p("Silk")};_.ja=function(){return _.p("Android")&&!(_.ha()||_.fa()||_.ca()||_.p("Silk"))};ka=function(){return _.p("iPhone")&&!_.p("iPod")&&!_.p("iPad")};_.la=function(){return ka()||_.p("iPad")||_.p("iPod")};',
#        '_.ma=function(a){var b=a.length;if(0<b){for(var c=Array(b)',
#        '_.ua=function(a',
#        ...
#        'try{', '_.Qj=function(a){var b', '}catch(e){_._DumpException(e)}',
#        'try{', 'var Rj=function(a', 'var Wj=_.F(_.ce',
#        '}catch(e){_._DumpException(e)}', '})(this.gbar_);', '// Google Inc.',
# ...

# %%
GDP2010.columns
# Out:
# Index(['index', 'try{', '/*', ' Copyright The Closure Library Authors.',
#        ' SPDX-License-Identifier: Apache-2.0', '*/', 'var ka',
#        '_.ia=function(){return _.p("Safari")&&!(_.ha()||_.p("Coast")||_.ca()||_.p("Edge")||_.p("Edg/")||_.p("OPR")||_.fa()||_.p("Silk")||_.p("Android"))};_.ha=function(){return(_.p("Chrome")||_.p("CriOS"))&&!_.p("Edge")||_.p("Silk")};_.ja=function(){return _.p("Android")&&!(_.ha()||_.fa()||_.ca()||_.p("Silk"))};ka=function(){return _.p("iPhone")&&!_.p("iPod")&&!_.p("iPad")};_.la=function(){return ka()||_.p("iPad")||_.p("iPod")};',
#        '_.ma=function(a){var b=a.length;if(0<b){for(var c=Array(b)',
#        '_.ua=function(a',
#        ...
#        'try{', '_.Qj=function(a){var b', '}catch(e){_._DumpException(e)}',
#        'try{', 'var Rj=function(a', 'var Wj=_.F(_.ce',
#        '}catch(e){_._DumpException(e)}', '})(this.gbar_);', '// Google Inc.',
# ...

# %%
GDP2010.columns = ['Tahun', 'Triwulan', 'A. Pertanian, Kehutanan, dan Perikanan',
                                          'B. Pertambangan dan Penggalian',
                                                  'C. Industri Pengolahan',
                                            'D. Pengadaan Listrik dan Gas',
             'E. Pengadaan Air, Pengelolaan Sampah, Limbah dan Daur Ulang',
                                                           'F. Konstruksi',
        'G. Perdagangan Besar dan Eceran; Reparasi Mobil dan Sepeda Motor',
                                        'H. Transportasi dan Pergudangan ',
                                 'I. Penyediaan Akomodasi dan Makan Minum',
                                             'J. Informasi dan Komunikasi',
                                           'K. Jasa Keuangan dan Asuransi',
                                                          'L. Real Estate',
                                                    'M,N. Jasa Perusahaan',
       'O. Administrasi Pemerintahan, Pertahanan dan Jaminan Sosial Wajib',
                                                      'P. Jasa Pendidikan',
                                   'Q. Jasa Kesehatan dan Kegiatan Sosial',
                                                   'R,S,T,U. Jasa lainnya',
                                  'A. NILAI TAMBAH BRUTO ATAS HARGA DASAR',
                                   'B. PAJAK DIKURANG SUBSIDI ATAS PRODUK',
                                                'C. PRODUK DOMESTIK BRUTO']

GDP2000.columns = ['Tahun', 'Triwulan', '1.PERTANIAN, PETERNAKAN, KEHUTANAN, PERIKANAN',
                       '2.PERTAMBANGAN DAN PENGGALIAN',
                               '3.INDUSTRI PENGOLAHAN',
                                          'a. Listrik',
                                         'b. Gas Kota',
                                       'c. Air Bersih',
                                        '5.KONSTRUKSI',
                     'a. Perdagangan Besar dan Eceran',
                                            'b. Hotel',
                                         'c. Restoran',
                                     'a. Pengangkutan',
                                       'b. Komunikasi',
                                             'a. Bank',
                      'b. Lembaga Keuangan Bukan Bank',
                          'c. Jasa Penunjang Keuangan',
                                      'd. Real Estate',
                                  'e. Jasa Perusahaan',
                                'a. Pemerintahan Umum',
                                           'b. Swasta',
                                                 'PDB',
                                     'PDB Tanpa Migas']

GDP2000.head(5)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-10-491e51fd8c1e> in <module>
# ----> 1 GDP2010.columns = ['Tahun', 'Triwulan', 'A. Pertanian, Kehutanan, dan Perikanan',
#       2                                           'B. Pertambangan dan Penggalian',
#       3                                                   'C. Industri Pengolahan',
#       4                                             'D. Pengadaan Listrik dan Gas',
#       5              'E. Pengadaan Air, Pengelolaan Sampah, Limbah dan Daur Ulang',
#
# /usr/local/lib/python3.8/dist-packages/pandas/core/generic.py in __setattr__(self, name, value)
#    5498         try:
#    5499             object.__getattribute__(self, name)
# -> 5500             return object.__setattr__(self, name, value)
#    5501         except AttributeError:
#    5502             pass
#
# ...

# %%
GDP2000_new = pd.DataFrame()
GDP2000_new['Tahun'] = GDP2000['Tahun']
GDP2000_new['Triwulan'] = GDP2000['Triwulan']
GDP2000_new['A. Pertanian, Kehutanan, dan Perikanan'] = GDP2000['1.PERTANIAN, PETERNAKAN, KEHUTANAN, PERIKANAN']
GDP2000_new['B. Pertambangan dan Penggalian'] = GDP2000['2.PERTAMBANGAN DAN PENGGALIAN']
GDP2000_new['C. Industri Pengolahan'] = GDP2000['3.INDUSTRI PENGOLAHAN']
GDP2000_new['D. Pengadaan Listrik dan Gas'] = GDP2000['a. Listrik'] + GDP2000['b. Gas Kota']
GDP2000_new['E. Pengadaan Air, Pengelolaan Sampah, Limbah dan Daur Ulang'] = GDP2000['c. Air Bersih']
GDP2000_new['F. Konstruksi'] = GDP2000['5.KONSTRUKSI']
GDP2000_new['G. Perdagangan Besar dan Eceran; Reparasi Mobil dan Sepeda Motor'] = GDP2000['a. Perdagangan Besar dan Eceran']
GDP2000_new['H. Transportasi dan Pergudangan '] = GDP2000['a. Pengangkutan']
GDP2000_new['I. Penyediaan Akomodasi dan Makan Minum'] = GDP2000['b. Hotel'] + GDP2000['c. Restoran']
GDP2000_new['J. Informasi dan Komunikasi'] = GDP2000['b. Komunikasi']
GDP2000_new['K. Jasa Keuangan dan Asuransi'] = GDP2000['a. Bank'] + GDP2000['b. Lembaga Keuangan Bukan Bank'] + GDP2000['c. Jasa Penunjang Keuangan']
GDP2000_new['L. Real Estate'] = GDP2000['d. Real Estate']
GDP2000_new['M,N. Jasa Perusahaan'] = GDP2000['e. Jasa Perusahaan']
GDP2000_new['O. Administrasi Pemerintahan, Pertahanan dan Jaminan Sosial Wajib'] = GDP2000['a. Pemerintahan Umum']
GDP2000_new['R,S,T,U. Jasa lainnya'] = GDP2000['b. Swasta']
GDP2000_new['C. PRODUK DOMESTIK BRUTO'] = GDP2000['PDB']
GDP2000_new

# %%
GDP2000
